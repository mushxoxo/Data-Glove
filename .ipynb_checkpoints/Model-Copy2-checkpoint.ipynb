# %%
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split

# %%
# Configs
DATA_PATH = "Database/img/"
SEQ_LEN = 300   # 3s @ 10ms = 300 steps
INPUT_DIM = 6
BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-3

# %%
# Load and preprocess data
sequences = []
labels = []

for filename in os.listdir(DATA_PATH):
    if filename.endswith('.csv'):
        path = os.path.join(DATA_PATH, filename)
        df = pd.read_csv(path, header=None, dtype=str)

        df = df.astype(str).apply(lambda col: col.map(lambda x: x.strip() if isinstance(x, str) else x))
        df = df.replace(r'[^\d\.-]', '', regex=True)
        df = df.apply(pd.to_numeric, errors='coerce')
        df = df.dropna()

        if df.shape[0] >= SEQ_LEN:
            df = df.iloc[:SEQ_LEN, :]
        else:
            pad = pd.DataFrame(np.zeros((SEQ_LEN - df.shape[0], df.shape[1])))
            df = pd.concat([df, pad], ignore_index=True)

        sequences.append(df.values.astype(np.float32))
        labels.append(filename.split('_')[0])

# %%
# Encode labels
label_to_idx = {label: idx for idx, label in enumerate(sorted(set(labels)))}
y_indices = [label_to_idx[label] for label in labels]

# %%
# Convert to tensors
X = torch.tensor(np.stack(sequences))  # [N, 300, 6]
y = torch.tensor(y_indices, dtype=torch.long)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: torch.Size([106, 300, 6])
# y shape: torch.Size([106])

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Compute mean and std using TRAIN data only
X_mean = X_train.mean(dim=(0, 1), keepdim=True)
X_std  = X_train.std(dim=(0, 1), keepdim=True)

print("Mean:", X_mean)
print("Std:", X_std)
# Out:
# Mean: tensor([[[  574.2746,  5040.1592, 14522.4648,   381.0427,   468.2150,
#            -114.0483]]])
# Std: tensor([[[222637.9688,   6486.7358,   5774.8428,  12030.2432,   7279.5894,
#             9448.4678]]])

# %%
# Prevent divide-by-zero
X_std = X_std + 1e-8

# Apply normalization
X_train = (X_train - X_mean) / X_std
X_test  = (X_test  - X_mean) / X_std

print("After normalization:")
print("Train mean:", X_train.mean(dim=(0,1)))
print("Train std :", X_train.std(dim=(0,1)))
# Out:
# After normalization:
# Train mean: tensor([ 4.5413e-10, -1.3412e-07, -2.0981e-07, -1.0672e-08,  8.6285e-09,
#          1.1732e-09])
# Train std : tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000])

# %%
# Dataset and DataLoader
class GestureDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_loader = DataLoader(GestureDataset(X_train, y_train), batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(GestureDataset(X_test, y_test), batch_size=BATCH_SIZE)

# %%
# LSTM model
class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
    def forward(self, x):
        _, (h_n, _) = self.lstm(x)
        return self.fc(h_n.squeeze(0))

model = LSTMClassifier(INPUT_DIM, 128, len(label_to_idx))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# LSTMClassifier(
#   (lstm): LSTM(6, 128, batch_first=True)
#   (fc): Linear(in_features=128, out_features=5, bias=True)
# )

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

train_losses = []
train_accuracies = []
test_accuracies = []

for epoch in range(EPOCHS):

    # ---- TRAIN ----
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for batch_X, batch_y in train_loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()

        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Accuracy
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == batch_y).sum().item()
        total += batch_y.size(0)

    avg_loss = total_loss / len(train_loader)
    train_acc = correct / total

    train_losses.append(avg_loss)
    train_accuracies.append(train_acc)

    # ---- EVALUATION ----
    model.eval()
    correct_test = 0
    total_test = 0

    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            outputs = model(batch_X)
            preds = torch.argmax(outputs, dim=1)

            correct_test += (preds == batch_y).sum().item()
            total_test += batch_y.size(0)

    test_acc = correct_test / total_test
    test_accuracies.append(test_acc)

    print(f"Epoch {epoch+1}/{EPOCHS} "
          f"- Loss: {avg_loss:.4f} "
          f"- Train Acc: {train_acc:.4f} "
          f"- Test Acc: {test_acc:.4f}")
# Out:
# Epoch 1/100 - Loss: 1.6047 - Train Acc: 0.2500 - Test Acc: 0.3636
# Epoch 2/100 - Loss: 1.5870 - Train Acc: 0.3810 - Test Acc: 0.4545
# Epoch 3/100 - Loss: 1.5683 - Train Acc: 0.3810 - Test Acc: 0.4091
# Epoch 4/100 - Loss: 1.5389 - Train Acc: 0.3810 - Test Acc: 0.4545
# Epoch 5/100 - Loss: 1.4873 - Train Acc: 0.3929 - Test Acc: 0.4545
# Epoch 6/100 - Loss: 1.4319 - Train Acc: 0.4405 - Test Acc: 0.4545
# Epoch 7/100 - Loss: 1.3094 - Train Acc: 0.4524 - Test Acc: 0.3636
# Epoch 8/100 - Loss: 1.1937 - Train Acc: 0.4286 - Test Acc: 0.3636
# Epoch 9/100 - Loss: 1.1858 - Train Acc: 0.4048 - Test Acc: 0.4545
# Epoch 10/100 - Loss: 1.0511 - Train Acc: 0.5833 - Test Acc: 0.5455
# Epoch 11/100 - Loss: 1.0205 - Train Acc: 0.5833 - Test Acc: 0.5000
# Epoch 12/100 - Loss: 0.9509 - Train Acc: 0.6071 - Test Acc: 0.5000
# Epoch 13/100 - Loss: 0.8907 - Train Acc: 0.5952 - Test Acc: 0.5000
# Epoch 14/100 - Loss: 0.7980 - Train Acc: 0.6071 - Test Acc: 0.5000
# Epoch 15/100 - Loss: 0.7726 - Train Acc: 0.5952 - Test Acc: 0.5000
# Epoch 16/100 - Loss: 0.8527 - Train Acc: 0.5476 - Test Acc: 0.5455
# Epoch 17/100 - Loss: 0.7297 - Train Acc: 0.6071 - Test Acc: 0.5000
# Epoch 18/100 - Loss: 0.7614 - Train Acc: 0.6548 - Test Acc: 0.5455
# Epoch 19/100 - Loss: 0.7323 - Train Acc: 0.6071 - Test Acc: 0.5000
# Epoch 20/100 - Loss: 0.7335 - Train Acc: 0.6190 - Test Acc: 0.5000
# Epoch 21/100 - Loss: 0.7170 - Train Acc: 0.5952 - Test Acc: 0.5000
# Epoch 22/100 - Loss: 0.7181 - Train Acc: 0.6310 - Test Acc: 0.5000
# Epoch 23/100 - Loss: 0.7002 - Train Acc: 0.6429 - Test Acc: 0.5000
# Epoch 24/100 - Loss: 0.7214 - Train Acc: 0.7024 - Test Acc: 0.5455
# Epoch 25/100 - Loss: 0.6642 - Train Acc: 0.6667 - Test Acc: 0.5455
# Epoch 26/100 - Loss: 0.6423 - Train Acc: 0.6786 - Test Acc: 0.5455
# Epoch 27/100 - Loss: 0.6919 - Train Acc: 0.6667 - Test Acc: 0.6818
# Epoch 28/100 - Loss: 0.6809 - Train Acc: 0.6548 - Test Acc: 0.6364
# Epoch 29/100 - Loss: 0.6646 - Train Acc: 0.6548 - Test Acc: 0.5909
# Epoch 30/100 - Loss: 0.6542 - Train Acc: 0.6905 - Test Acc: 0.5455
# Epoch 31/100 - Loss: 0.6229 - Train Acc: 0.6905 - Test Acc: 0.5909
# Epoch 32/100 - Loss: 0.6111 - Train Acc: 0.7024 - Test Acc: 0.5455
# Epoch 33/100 - Loss: 0.6763 - Train Acc: 0.6190 - Test Acc: 0.4545
# Epoch 34/100 - Loss: 0.6572 - Train Acc: 0.6548 - Test Acc: 0.5455
# Epoch 35/100 - Loss: 0.6417 - Train Acc: 0.7143 - Test Acc: 0.5000
# Epoch 36/100 - Loss: 0.5867 - Train Acc: 0.6786 - Test Acc: 0.5909
# Epoch 37/100 - Loss: 0.6014 - Train Acc: 0.6786 - Test Acc: 0.5909
# Epoch 38/100 - Loss: 0.6139 - Train Acc: 0.7143 - Test Acc: 0.6364
# Epoch 39/100 - Loss: 0.5923 - Train Acc: 0.7619 - Test Acc: 0.7727
# Epoch 40/100 - Loss: 0.5749 - Train Acc: 0.7381 - Test Acc: 0.6818
# Epoch 41/100 - Loss: 0.5746 - Train Acc: 0.7143 - Test Acc: 0.6364
# Epoch 42/100 - Loss: 0.5517 - Train Acc: 0.7024 - Test Acc: 0.6364
# Epoch 43/100 - Loss: 0.5463 - Train Acc: 0.7381 - Test Acc: 0.5909
# Epoch 44/100 - Loss: 0.5046 - Train Acc: 0.7381 - Test Acc: 0.6364
# Epoch 45/100 - Loss: 0.4914 - Train Acc: 0.7500 - Test Acc: 0.6818
# Epoch 46/100 - Loss: 0.5124 - Train Acc: 0.7024 - Test Acc: 0.5909
# Epoch 47/100 - Loss: 0.5181 - Train Acc: 0.7500 - Test Acc: 0.6364
# Epoch 48/100 - Loss: 0.4709 - Train Acc: 0.7857 - Test Acc: 0.6818
# Epoch 49/100 - Loss: 0.4785 - Train Acc: 0.7381 - Test Acc: 0.6818
# Epoch 50/100 - Loss: 0.4260 - Train Acc: 0.7857 - Test Acc: 0.6364
# Epoch 51/100 - Loss: 0.4930 - Train Acc: 0.7857 - Test Acc: 0.7727
# Epoch 52/100 - Loss: 0.4109 - Train Acc: 0.7857 - Test Acc: 0.5909
# Epoch 53/100 - Loss: 0.3998 - Train Acc: 0.8214 - Test Acc: 0.6818
# Epoch 54/100 - Loss: 0.3590 - Train Acc: 0.8571 - Test Acc: 0.7273
# Epoch 55/100 - Loss: 0.3927 - Train Acc: 0.8214 - Test Acc: 0.7727
# Epoch 56/100 - Loss: 0.3049 - Train Acc: 0.8333 - Test Acc: 0.6818
# Epoch 57/100 - Loss: 0.2993 - Train Acc: 0.8810 - Test Acc: 0.6818
# Epoch 58/100 - Loss: 0.2991 - Train Acc: 0.8333 - Test Acc: 0.6364
# Epoch 59/100 - Loss: 0.2941 - Train Acc: 0.8810 - Test Acc: 0.6818
# Epoch 60/100 - Loss: 0.2495 - Train Acc: 0.9167 - Test Acc: 0.6818
# Epoch 61/100 - Loss: 0.2617 - Train Acc: 0.9048 - Test Acc: 0.7727
# Epoch 62/100 - Loss: 0.1881 - Train Acc: 0.9643 - Test Acc: 0.8182
# Epoch 63/100 - Loss: 0.2175 - Train Acc: 0.9405 - Test Acc: 0.7727
# Epoch 64/100 - Loss: 0.5181 - Train Acc: 0.8452 - Test Acc: 0.7273
# Epoch 65/100 - Loss: 0.7977 - Train Acc: 0.7857 - Test Acc: 0.5909
# Epoch 66/100 - Loss: 0.7973 - Train Acc: 0.7024 - Test Acc: 0.7273
# Epoch 67/100 - Loss: 0.3124 - Train Acc: 0.9167 - Test Acc: 0.5455
# Epoch 68/100 - Loss: 0.4720 - Train Acc: 0.8095 - Test Acc: 0.7273
# Epoch 69/100 - Loss: 0.5031 - Train Acc: 0.8095 - Test Acc: 0.6364
# Epoch 70/100 - Loss: 0.5445 - Train Acc: 0.8095 - Test Acc: 0.6818
# Epoch 71/100 - Loss: 0.4987 - Train Acc: 0.8095 - Test Acc: 0.7273
# Epoch 72/100 - Loss: 0.4890 - Train Acc: 0.8333 - Test Acc: 0.7273
# Epoch 73/100 - Loss: 0.4230 - Train Acc: 0.8333 - Test Acc: 0.7273
# Epoch 74/100 - Loss: 0.4377 - Train Acc: 0.7976 - Test Acc: 0.7273
# Epoch 75/100 - Loss: 0.4155 - Train Acc: 0.8095 - Test Acc: 0.6818
# Epoch 76/100 - Loss: 0.3366 - Train Acc: 0.8214 - Test Acc: 0.6364
# Epoch 77/100 - Loss: 0.3787 - Train Acc: 0.8214 - Test Acc: 0.6364
# Epoch 78/100 - Loss: 0.4101 - Train Acc: 0.7738 - Test Acc: 0.5000
# Epoch 79/100 - Loss: 0.5345 - Train Acc: 0.7381 - Test Acc: 0.6364
# Epoch 80/100 - Loss: 0.4269 - Train Acc: 0.8452 - Test Acc: 0.6364
# Epoch 81/100 - Loss: 0.4663 - Train Acc: 0.8214 - Test Acc: 0.8182
# Epoch 82/100 - Loss: 0.5015 - Train Acc: 0.8214 - Test Acc: 0.7727
# Epoch 83/100 - Loss: 0.3646 - Train Acc: 0.8690 - Test Acc: 0.8182
# Epoch 84/100 - Loss: 0.3743 - Train Acc: 0.8333 - Test Acc: 0.7727
# Epoch 85/100 - Loss: 0.3536 - Train Acc: 0.8452 - Test Acc: 0.7727
# Epoch 86/100 - Loss: 0.3130 - Train Acc: 0.8929 - Test Acc: 0.7727
# Epoch 87/100 - Loss: 0.2740 - Train Acc: 0.9048 - Test Acc: 0.7727
# Epoch 88/100 - Loss: 0.2443 - Train Acc: 0.9643 - Test Acc: 0.7727
# Epoch 89/100 - Loss: 0.2014 - Train Acc: 0.9881 - Test Acc: 0.7727
# Epoch 90/100 - Loss: 0.1716 - Train Acc: 0.9881 - Test Acc: 0.7273
# Epoch 91/100 - Loss: 0.1507 - Train Acc: 0.9881 - Test Acc: 0.7273
# Epoch 92/100 - Loss: 0.1147 - Train Acc: 0.9881 - Test Acc: 0.7727
# Epoch 93/100 - Loss: 0.1835 - Train Acc: 0.9762 - Test Acc: 0.7273
# Epoch 94/100 - Loss: 0.0891 - Train Acc: 0.9881 - Test Acc: 0.7273
# Epoch 95/100 - Loss: 0.1948 - Train Acc: 0.9286 - Test Acc: 0.7273
# Epoch 96/100 - Loss: 0.1468 - Train Acc: 0.9405 - Test Acc: 0.7727
# Epoch 97/100 - Loss: 0.1234 - Train Acc: 0.9643 - Test Acc: 0.8636
# Epoch 98/100 - Loss: 0.0799 - Train Acc: 0.9881 - Test Acc: 0.8636
# Epoch 99/100 - Loss: 0.0683 - Train Acc: 1.0000 - Test Acc: 0.8636
# Epoch 100/100 - Loss: 0.0615 - Train Acc: 1.0000 - Test Acc: 0.8636

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(train_losses)
plt.title("Training Loss")

plt.subplot(1,2,2)
plt.plot(train_accuracies, label="Train")
plt.plot(test_accuracies, label="Test")
plt.title("Accuracy")
plt.legend()

plt.show()

# %%
# Save model AFTER training
torch.save(model.state_dict(), "data_glove_lstm.pth")

# %%
# Evaluation
model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        outputs = model(batch_X)
        preds = torch.argmax(outputs, dim=1).cpu()
        all_preds.extend(preds.numpy())
        all_targets.extend(batch_y.numpy())

acc = accuracy_score(all_targets, all_preds)
print(f"\nTest Accuracy: {acc:.4f}")

# Generate target names from label_to_idx
idx_to_label = {v: k for k, v in label_to_idx.items()}
target_names = [idx_to_label[i] for i in range(len(idx_to_label))]

print("\nClassification Report:\n", classification_report(all_targets, all_preds, target_names=target_names))
# Out:
# Test Accuracy: 0.8636
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         4
#            B       0.80      1.00      0.89         4
#            C       0.75      0.75      0.75         4
#            D       1.00      0.80      0.89         5
#            E       0.80      0.80      0.80         5
#
#     accuracy                           0.86        22
#    macro avg       0.87      0.87      0.87        22
# weighted avg       0.87      0.86      0.86        22

# %%
# Predict and print results for the test set
print("\nPredictions on Test Set:")
for i in range(len(all_preds)):
    true_label = idx_to_label[all_targets[i]]
    predicted_label = idx_to_label[all_preds[i]]
    print(f"{i+1}: True = {true_label}, Predicted = {predicted_label}")
# Out:
# Predictions on Test Set:
# 1: True = D, Predicted = D
# 2: True = E, Predicted = E
# 3: True = C, Predicted = C
# 4: True = E, Predicted = C
# 5: True = D, Predicted = D
# 6: True = B, Predicted = B
# 7: True = A, Predicted = A
# 8: True = C, Predicted = C
# 9: True = E, Predicted = E
# 10: True = E, Predicted = E
# 11: True = C, Predicted = C
# 12: True = D, Predicted = D
# 13: True = B, Predicted = B
# 14: True = D, Predicted = B
# 15: True = B, Predicted = B
# 16: True = A, Predicted = A
# 17: True = A, Predicted = A
# 18: True = A, Predicted = A
# 19: True = B, Predicted = B
# 20: True = C, Predicted = E
# 21: True = E, Predicted = E
# 22: True = D, Predicted = D

# %%
print("\nIncorrect Predictions:")
for i in range(len(all_preds)):
    if all_preds[i] != all_targets[i]:
        true_label = idx_to_label[all_targets[i]]
        predicted_label = idx_to_label[all_preds[i]]
        print(f"Sample {i+1}: True = {true_label}, Predicted = {predicted_label}")
# Out:
# Incorrect Predictions:
# Sample 4: True = E, Predicted = C
# Sample 14: True = D, Predicted = B
# Sample 20: True = C, Predicted = E

# %%
torch.save(model.state_dict(), "data_glove_lstm.pth")
